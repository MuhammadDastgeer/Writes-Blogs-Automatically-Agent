# %%
from langchain_community.tools.tavily_search import TavilySearchResults
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
tool = TavilySearch(max_results=2)
results = tool.invoke({"query": 'ChatGPT version releases and updates from 2022 to 2026'})
results
# Out:
# {'query': 'ChatGPT version releases and updates from 2022 to 2026',
#  'response_time': 1.52,
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://en.wikipedia.org/wiki/ChatGPT',
#    'title': 'ChatGPT',
#    'content': 'Main model versions of ChatGPT with descriptions| Version | Release date | Status( | Description |\n ---  --- |\n| GPT-3.5 | November 2022 | Discontinued | The first model used in ChatGPT.( |\n| GPT-4 | March 2023 | Discontinued | Introduced in March 2023.( |\n| GPT-4o | May 2024 | Legacy support | Capable of processing text, image, audio, and video, GPT-4o is faster and more capable than GPT-4.( |\n| GPT-4o mini | July 2024 | Discontinued | A smaller and cheaper version of GPT-4o. GPT-4o mini replaced GPT-3.5 in the July 2024 version of ChatGPT.( |\n| o1-preview | September 2024 | Discontinued | A pre-release version of OpenAI o1, an updated version that could "think" before responding to requests.( |\n| o1-mini | September 2024 | Discontinued | A smaller and faster version of OpenAI o1.( | [...] | GPT-5 | August 7, 2025 | Legacy support | Flagship model replacing all previous available models. The versions GPT-5 Instant, GPT-5 Thinking and GPT-5 Pro affect the reasoning time. The default version GPT-5 Auto uses a router to determine how much reasoning is needed, based on the complexity of the request.( |\n| GPT-5 mini | August 7, 2025 | Active | Faster, more cost-efficient version of GPT-5. |\n| GPT-5.1 | November 12, 2025 | Legacy support | Warmer and better at following instructions according to OpenAI. Allows users to select alternative personalities.( |\n| GPT-5.2 | December 11, 2025 | Active |\n| GPT-5.3-Codex | February 05, 2026( | Active |  |',
#    'score': 0.99972624,
#    'raw_content': None},
#   {'url': 'https://help.openai.com/en/articles/6825453-chatgpt-release-notes',
#    'title': 'ChatGPT — Release Notes',
#    'content': 'Nov 22, 2024\n   Updates to the ChatGPT Web experience\n   Sidebar redesign\n   Other updates for ChatGPT on Web\n   Improved Mobile Web Experience\n   Nov 19, 2024\n   Advanced Voice for ChatGPT Web\n   Aug 8, 2024\n   DALL·E 3 for ChatGPT Free users\n   July 18, 2024\n   Introducing GPT-4o mini\n   May 16, 2024\n   Improvements to data analysis in ChatGPT\n   May 13, 2024\n   Introducing GPT-4o\n   Apr 29, 2024\n   Memory is now available to Plus users\n   Apr 1, 2024\n   Start using ChatGPT instantly\n   Feb 13, 2024\n   Memory and new controls for ChatGPT\n   Jan 10, 2024\n   Introducing the GPT Store and ChatGPT Team plan\n   November 21, 2023\n   ChatGPT with voice is available to all users\n   November 6, 2023\n   Introducing GPTs\n   October 17, 2023\n   Browsing is now out of beta\n   October 16, 2023 [...] February 4, 2026\n   Update on thinking time settings for GPT-5.2 Thinking in ChatGPT\n   February 2, 2026\n   Introducing the Codex app\n   January 30, 2026\n   More visual responses\n   January 29, 2026\n   Retiring GPT-4o and other legacy models\n   January 26, 2026\n   Improvements to search response quality in Voice\n   January 22, 2026\n   5.2 Personality System Prompt Update\n   January 20, 2026\n   Voice Updates\n   Rolling out age prediction\n   January 15, 2026\n   Improved memory for finding details from past chats (Plus & Pro)\n   January 12, 2026\n   Dictation Updates\n   January 7, 2026\n   Health in ChatGPT\n   December 22, 2025\n   Your Year with ChatGPT\n   December 19, 2025\n   New detailed characteristic controls\n   December 18, 2025\n   Introducing the app directory in ChatGPT [...] Code interpreter is now rolling out in beta on web\n   July 3, 2023\n   Browsing is temporarily disabled\n   June 22, 2023\n   Browsing and search on mobile\n   May 24, 2023\n   iOS app available in more countries, shared links in alpha, Bing Plugin, disable history on iOS\n   May 12, 2023\n   Web browsing and Plugins are now rolling out in beta\n   May 3, 2023\n   Updates to ChatGPT\n   March 23, 2023\n   Introducing plugins in ChatGPT\n   March 14, 2023\n   Announcing GPT-4 in ChatGPT\n   Feb 13, 2023\n   Updates to ChatGPT\n   Feb 9 2023\n   Introducing ChatGPT Plus\n   Jan 30, 2023\n   Factuality and mathematical improvements\n   Jan 9, 2023\n   Updates to ChatGPT\n   Dec 15, 2022\n   Performance updates to ChatGPT',
#    'score': 0.9991374,
#    'raw_content': None}],
#  'request_id': 'ff3e3fa0-c9aa-408f-a00b-779a41192f44'}
